# %%
import pandas as pd

# %% [markdown]
# importing the file which contains the patients id for tumor and normal samples

# %%
normal1 =pd.read_csv('normal.csv')
tumor1 =pd.read_csv('tumor1.csv')

# %%
tumor1
# Out:
#                             tumor    id
# 0    TCGA-05-5420-01A-01R-1628-07  5420
# 1    TCGA-55-7283-01A-11R-2039-07  7283
# 2    TCGA-55-8208-01A-11R-2241-07  8208
# 3    TCGA-75-6205-01A-11R-1755-07  6205
# 4    TCGA-44-8117-01A-11R-2241-07  8117
# ..                            ...   ...
# 498  TCGA-86-8056-01A-11R-2241-07  8056
# 499  TCGA-64-5815-01A-01R-1628-07  5815
# 500  TCGA-44-3398-01A-01R-1107-07  3398
# 501  TCGA-55-6970-01A-11R-1949-07  6970
# 502  TCGA-64-1680-01A-02R-0946-07  1680
#
# [503 rows x 2 columns]

# %% [markdown]
# importing the gene expression files for tumor and normal samples

# %%
tumor2 =pd.read_csv('luad_T.csv')
normal2 =pd.read_csv('luad_N.csv')

# %%
df = tumor2.set_index(['Hugo_Symbol','Entrez_Gene_Id'])

# %%
df2 = normal2.set_index(['Hugo_Symbol','Entrez_Gene_Id'])

# %%
df
# Out:
#                               TCGA-05-5420-01A-01R-1628-07  \
# Hugo_Symbol   Entrez_Gene_Id
# HIST3H2A      92815                                 842.36
# LIN7B         64130                                 417.77
# LXN           56925                                1135.20
# CNKSR2        22866                                   2.39
# SCML1         6322                                  384.34
# ...                                                    ...
# HAVCR2        84868                                 909.17
# RP1-66C13.4   0                                       0.00
# C3orf79       152118                                  0.00
# CTD-2116N17.1 0                                      12.45
# FUT2          2524                                  500.46
#
#                               TCGA-55-7283-01A-11R-2039-07  \
# Hugo_Symbol   Entrez_Gene_Id
# HIST3H2A      92815                                   8.25
# LIN7B         64130                                  68.55
# ...

# %%
normal1['id'].to_list()
# Out:
# [6980,
#  6984,
#  5936,
#  6849,
#  6968,
#  5930,
#  6745,
#  5931,
#  6778,
#  5939,
#  2655,
#  6829,
#  3398,
#  5935,
#  6761,
#  6744,
#  5645,
#  4627,
#  6972,
#  6836,
#  2665,
#  6970,
#  2657,
#  6969,
#  6776,
#  6835,
#  6847,
#  6146,
#  6986,
#  6828,
#  2668,
#  6981,
#  6971,
#  6831,
#  6144,
#  4676,
#  4632,
#  6743,
#  4512,
#  6975,
#  6742,
#  5933,
#  4490,
#  5932,
#  6595,
#  6777,
#  4625,
#  6145,
#  6978,
#  6148,
#  6979,
#  6983,
#  6982,
#  2662,
#  3396,
#  2661,
#  4626,
#  6985,
#  6147]

# %%
tumor1['id'].to_list()
# Out:
# ['5420',
#  '7283',
#  '8208',
#  '6205',
#  '8117',
#  'A4TA',
#  '8669',
#  '8668',
#  'A4SS',
#  '7227',
#  '5936',
#  'A48Z',
#  'A4TF',
#  'A4M7',
#  '7763',
#  'A46O',
#  '7536',
#  '8172',
#  '8067',
#  'A4YP',
#  '4420',
#  'A444',
#  '6744',
#  'A4TK',
#  '7626',
#  '8302',
#  '3770',
#  '8648',
#  '4510',
#  '5045',
#  '8039',
#  '6206',
#  'A4TC',
#  '7039',
#  '7669',
#  'A4LX',
#  '2662',
#  '8614',
#  '7815',
#  '4658',
#  '1592',
#  '6840',
#  '8585',
#  '6146',
#  '8398',
#  '7145',
#  '6543',
#  '8054',
#  '7161',
#  'A4D0',
#  '4628',
#  '8255',
#  'A4P8',
#  '7661',
#  '6774',
#  'A4JQ',
#  '7547',
#  'A4T7',
#  '7348',
#  '4398',
#  '3773',
#  '6593',
#  '6776',
#  'A4YG',
#  '4389',
#  '7659',
#  '2662',
#  '8459',
#  '7573',
#  'A4VK',
#  '8674',
#  '8254',
#  '6828',
#  '7030',
#  'A4M3',
#  '4626',
#  '6148',
#  '7159',
#  'A4TI',
#  '7153',
#  'A4JF',
#  '5944',
#  '5051',
#  '2668',
#  'A4M6',
#  'A46Y',
#  '8510',
#  '6212',
#  '7624',
#  '4487',
# ...

# %% [markdown]
# adding the patients id row for each samples in tumor and normal gene expression data frame

# %%
df.loc['id'] = ['5420',
 '7283',
 '8208',
 '6205',
 '8117',
 'A4TA',
 '8669',
 '8668',
 'A4SS',
 '7227',
 '5936',
 'A48Z',
 'A4TF',
 'A4M7',
 '7763',
 'A46O',
 '7536',
 '8172',
 '8067',
 'A4YP',
 '4420',
 'A444',
 '6744',
 'A4TK',
 '7626',
 '8302',
 '3770',
 '8648',
 '4510',
 '5045',
 '8039',
 '6206',
 'A4TC',
 '7039',
 '7669',
 'A4LX',
 '2662',
 '8614',
 '7815',
 '4658',
 '1592',
 '6840',
 '8585',
 '6146',
 '8398',
 '7145',
 '6543',
 '8054',
 '7161',
 'A4D0',
 '4628',
 '8255',
 'A4P8',
 '7661',
 '6774',
 'A4JQ',
 '7547',
 'A4T7',
 '7348',
 '4398',
 '3773',
 '6593',
 '6776',
 'A4YG',
 '4389',
 '7659',
 '2662',
 '8459',
 '7573',
 'A4VK',
 '8674',
 '8254',
 '6828',
 '7030',
 'A4M3',
 '4626',
 '6148',
 '7159',
 'A4TI',
 '7153',
 'A4JF',
 '5944',
 '5051',
 '2668',
 'A4M6',
 'A46Y',
 '8510',
 '6212',
 '7624',
 '4487',
 '6591',
 '7938',
 '1678',
 'A456',
 '7031',
 '8203',
 '8120',
 '3615',
 '5942',
 '6642',
 '6777',
 '6971',
 '7271',
 '5611',
 '7150',
 'A9RS',
 'A4SV',
 '6849',
 '5715',
 '6835',
 '6214',
 '7570',
 '6981',
 '6673',
 '8616',
 'AA5R',
 '5933',
 '7760',
 '7155',
 '8025',
 '8547',
 '7771',
 'A490',
 '7662',
 'A493',
 '1595',
 '7973',
 '6972',
 '6147',
 '3774',
 '2668',
 '6969',
 '6216',
 'A5C7',
 'A46V',
 'A46R',
 'A4DG',
 '7672',
 '7913',
 '8496',
 '3917',
 '7156',
 '6968',
 '2666',
 '4397',
 'A4M0',
 '6217',
 '7146',
 '6978',
 '5126',
 '6986',
 '8507',
 '5939',
 '8359',
 '4244',
 '7147',
 '7109',
 '7726',
 '8096',
 '6831',
 '5781',
 '6979',
 '8281',
 '4123',
 'A47A',
 '4410',
 '2656',
 '7553',
 '8671',
 '7761',
 '8453',
 '5125',
 '5375',
 '6980',
 'A47G',
 '7542',
 'A4T9',
 '3919',
 '4433',
 'A48Y',
 '7911',
 '6987',
 'A4TH',
 'A4BC',
 '6830',
 '4625',
 '7281',
 '7974',
 '4670',
 '5932',
 '6145',
 '8615',
 'A4YF',
 '5607',
 '6982',
 '4403',
 '7576',
 '4427',
 '6847',
 '5908',
 '8619',
 '6590',
 '8299',
 'A4JP',
 'A4T6',
 '8074',
 '7953',
 'AARN',
 '5055',
 '7903',
 '8278',
 '6745',
 '8620',
 '8397',
 'AAR3',
 '8402',
 '6215',
 '8177',
 '5429',
 '7701',
 '7554',
 '1679',
 'A59K',
 '6984',
 'A4VN',
 '7284',
 '7727',
 'A4M1',
 '6767',
 'A4AG',
 '8089',
 '8207',
 '7027',
 '7955',
 '5147',
 '8076',
 '5608',
 '5941',
 'A5IP',
 '8399',
 'AAR9',
 '8279',
 '4630',
 '6742',
 'A4E6',
 'A4SU',
 '7574',
 '8280',
 '1594',
 '4112',
 '8085',
 '4395',
 '7162',
 '2659',
 '6848',
 '5425',
 'A491',
 '8179',
 '8192',
 '8460',
 '5428',
 'A52J',
 '4396',
 'AAQV',
 '2655',
 '4402',
 'A4TE',
 '8514',
 '7941',
 '4425',
 '6983',
 '7937',
 '7562',
 '7143',
 '8033',
 '6725',
 '4486',
 '8090',
 '8073',
 '2665',
 '7499',
 'AA1A',
 '6775',
 '7994',
 'A494',
 '6203',
 '5930',
 '3771',
 '4625',
 '7978',
 '7540',
 '7160',
 '8513',
 '4631',
 '5644',
 '8075',
 '5779',
 '5423',
 '4434',
 '4249',
 '4675',
 '3918',
 '8662',
 '8395',
 '7148',
 '3918',
 '7907',
 'A4AD',
 '4666',
 '6779',
 '4662',
 '7816',
 'AARO',
 '5049',
 '6712',
 '4424',
 '7667',
 '8032',
 '6178',
 '6147',
 'A4YQ',
 '8171',
 '1681',
 '7979',
 '4426',
 '8092',
 'A4SY',
 '7948',
 '6851',
 '5931',
 '4506',
 '6592',
 'AAR4',
 '7025',
 'AAR0',
 '8055',
 '7947',
 'A4DF',
 '4250',
 '4677',
 '7724',
 '5774',
 '6985',
 '8520',
 '5935',
 '7552',
 'A46U',
 '8094',
 'A4TJ',
 '8457',
 '7944',
 '8512',
 '8621',
 '4668',
 'A50W',
 '4659',
 'A4AE',
 '8206',
 '4384',
 'A479',
 '2665',
 '8176',
 '1596',
 'AARR',
 '6778',
 '5146',
 '8640',
 'A4E5',
 '4490',
 '7765',
 '8506',
 'A4YI',
 '5899',
 '7498',
 '8497',
 '8499',
 '3396',
 '7539',
 '7711',
 'A4N4',
 '8119',
 '6595',
 '7728',
 'A4T8',
 '6975',
 '7671',
 '4679',
 '7914',
 'A93V',
 '4432',
 '7660',
 '7980',
 'A4P7',
 '6207',
 '4676',
 '4112',
 '7220',
 '8655',
 '7537',
 '5946',
 '8552',
 '8672',
 'AARE',
 '2666',
 '8097',
 '2656',
 '8087',
 '4430',
 '4501',
 '7910',
 '8505',
 '6775',
 '7158',
 '6836',
 '4405',
 '4418',
 'A4JN',
 'A472',
 'A55R',
 '4417',
 'A55A',
 '8174',
 '4122',
 '2657',
 'A4N5',
 '4382',
 'A4EZ',
 '8205',
 'A4TD',
 '7458',
 '4632',
 '8091',
 '8175',
 '4422',
 'A471',
 '8508',
 '7347',
 'A7SV',
 'A8F4',
 '7670',
 'A4JO',
 '4488',
 '7546',
 '8301',
 '4494',
 '6761',
 '5643',
 'A47B',
 '7043',
 'A4SW',
 '8494',
 '4629',
 '5775',
 'A4T4',
 'A55O',
 '8358',
 '4627',
 '4390',
 '6562',
 '7633',
 '7152',
 '7567',
 'A48X',
 '8253',
 '7725',
 '7995',
 '6594',
 'A57B',
 '7167',
 '7714',
 '5122',
 'A4M5',
 '8394',
 'A46S',
 '5072',
 '8660',
 '8194',
 '3772',
 '6829',
 '6743',
 'A7XG',
 '5066',
 '4505',
 '4415',
 '7154',
 '6211',
 '5068',
 'A743',
 'A4M2',
 '5645',
 '2661',
 '8204',
 '8511',
 '7163',
 '5645',
 '7713',
 '7764',
 '7954',
 '8056',
 '5815',
 '3398',
 '6970',
 '1680']

# %%
df2.loc['id'] =['6980',
 '6984',
 '5936',
 '6849',
 '6968',
 '5930',
 '6745',
 '5931',
 '6778',
 '5939',
 '2655',
 '6829',
 '3398',
 '5935',
 '6761',
 '6744',
 '5645',
 '4627',
 '6972',
 '6836',
 '2665',
 '6970',
 '2657',
 '6969',
 '6776',
 '6835',
 '6847',
 '6146',
 '6986',
 '6828',
 '2668',
 '6981',
 '6971',
 '6831',
 '6144',
 '4676',
 '4632',
 '6743',
 '4512',
 '6975',
 '6742',
 '5933',
 '4490',
 '5932',
 '6595',
 '6777',
 '4625',
 '6145',
 '6978',
 '6148',
 '6979',
 '6983',
 '6982',
 '2662',
 '3396',
 '2661',
 '4626',
 '6985',
 '6147']

# %%
df2
# Out:
#                    TCGA-55-6980-11A-01R-1949-07 TCGA-55-6984-11A-01R-1949-07  \
# (HIST3H2A, 92815)                         48.52                        76.17
# (LIN7B, 64130)                            186.4                        134.3
# (LXN, 56925)                             536.45                       629.35
# (CNKSR2, 22866)                           48.52                        53.19
# (SCML1, 6322)                            241.19                       166.73
# ...                                         ...                          ...
# (RP1-66C13.4, 0)                            0.0                          0.0
# (C3orf79, 152118)                           0.0                          0.0
# (CTD-2116N17.1, 0)                          0.0                         1.41
# (FUT2, 2524)                              28.24                        40.64
# id                                         6980                         6984
#
# ...

# %%
df
# Out:
#                    TCGA-05-5420-01A-01R-1628-07 TCGA-55-7283-01A-11R-2039-07  \
# (HIST3H2A, 92815)                        842.36                         8.25
# (LIN7B, 64130)                           417.77                        68.55
# (LXN, 56925)                             1135.2                       339.14
# (CNKSR2, 22866)                            2.39                         9.93
# (SCML1, 6322)                            384.34                        60.82
# ...                                         ...                          ...
# (RP1-66C13.4, 0)                            0.0                          0.0
# (C3orf79, 152118)                           0.0                          0.0
# (CTD-2116N17.1, 0)                        12.45                         3.96
# (FUT2, 2524)                             500.46                       406.31
# id                                         5420                         7283
#
# ...

# %% [markdown]
# transpose the dataframe for easy calculation for patientwise

# %%
t = df.T

# %%
t2 = df2.T

# %%
t.index.name = 'case_barcode'

# %%
t
# Out:
#                              (HIST3H2A, 92815) (LIN7B, 64130) (LXN, 56925)  \
# case_barcode
# TCGA-05-5420-01A-01R-1628-07            842.36         417.77       1135.2
# TCGA-55-7283-01A-11R-2039-07              8.25          68.55       339.14
# TCGA-55-8208-01A-11R-2241-07             36.27         214.27      1498.22
# TCGA-75-6205-01A-11R-1755-07             127.0         128.79       543.96
# TCGA-44-8117-01A-11R-2241-07             13.42         157.68       291.04
# ...                                        ...            ...          ...
# TCGA-86-8056-01A-11R-2241-07             19.11         140.04       555.41
# TCGA-64-5815-01A-01R-1628-07             11.55         108.14       830.75
# TCGA-44-3398-01A-01R-1107-07            137.14          277.2      1977.24
# TCGA-55-6970-01A-11R-1949-07            480.04          78.89       454.09
# TCGA-64-1680-01A-02R-0946-07            215.77          82.29       373.81
#
# ...

# %%
id= ["3396","6777","6984","5645","5936","6147","6743","6981","6849","6595","6847","6969","6978","2665","6831","5930","2657","4627","6742","6983","6979","6970","6968","6975","6980","3398","6971","6828","4676","5931","6148","6776","2668","6745","2661","6145","2655","4490","5935","4625","6986","6829","4626","6985","6744","5932","6836","5933","6778","6146","6972","4632","6761","6835","6982","5939","2662"]

# %%
f_d = t.reset_index()

# %%
e = f_d.set_index(['id'])

# %%
e
# Out:
#                       case_barcode (HIST3H2A, 92815) (LIN7B, 64130)  \
# id
# 5420  TCGA-05-5420-01A-01R-1628-07            842.36         417.77
# 7283  TCGA-55-7283-01A-11R-2039-07              8.25          68.55
# 8208  TCGA-55-8208-01A-11R-2241-07             36.27         214.27
# 6205  TCGA-75-6205-01A-11R-1755-07             127.0         128.79
# 8117  TCGA-44-8117-01A-11R-2241-07             13.42         157.68
# ...                            ...               ...            ...
# 8056  TCGA-86-8056-01A-11R-2241-07             19.11         140.04
# 5815  TCGA-64-5815-01A-01R-1628-07             11.55         108.14
# 3398  TCGA-44-3398-01A-01R-1107-07            137.14          277.2
# 6970  TCGA-55-6970-01A-11R-1949-07            480.04          78.89
# 1680  TCGA-64-1680-01A-02R-0946-07            215.77          82.29
#
#      (LXN, 56925) (CNKSR2, 22866) (SCML1, 6322) (AC024592.12, 0)  \
# id
# 5420       1135.2            2.39        384.34           104.42
# ...

# %% [markdown]
# groupby id and take the mean of the values of duplicate patient ids

# %%
final = e.groupby('id').agg('mean')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py:507: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)

# %%
final_df = final.reset_index()

# %%
m_t = final_df[final_df['id'].isin(["3396","6777","6984","5645","5936","6147","6743","6981","6849","6595","6847","6969","6978","2665","6831","5930","2657","4627","6742","6983","6979","6970","6968","6975","6980","3398","6971","6828","4676","5931","6148","6776","2668","6745","2661","6145","2655","4490","5935","4625","6986","6829","4626","6985","6744","5932","6836","5933","6778","6146","6972","4632","6761","6835","6982","5939","2662"])]

# %%
m_t
# Out:
#        id  (HIST3H2A, 92815)  (LIN7B, 64130)  (LXN, 56925)  (CNKSR2, 22866)  \
# 8    2655             15.340         109.660       830.750            3.860
# 10   2657            187.710         256.780       713.110           21.010
# 12   2661            142.010         273.370      1233.750           12.180
# 13   2662            787.655          88.190      1019.955            5.120
# 14   2665            334.580         116.910       904.965            4.635
# 16   2668            590.730          41.180       705.330            3.200
# 17   3396             66.180         133.360      1008.900            2.580
# 18   3398            137.140         277.200      1977.240            6.060
# 62   4490            209.840         159.900       423.610            5.590
# 68   4625              0.375           0.210         0.125            0.075
# 69   4626             73.540         115.970       928.300            5.820
# ...

# %%
m_t.set_index(['id'],inplace = True)

# %%
m_t
# Out:
#       (HIST3H2A, 92815)  (LIN7B, 64130)  (LXN, 56925)  (CNKSR2, 22866)  \
# id
# 2655             15.340         109.660       830.750            3.860
# 2657            187.710         256.780       713.110           21.010
# 2661            142.010         273.370      1233.750           12.180
# 2662            787.655          88.190      1019.955            5.120
# 2665            334.580         116.910       904.965            4.635
# 2668            590.730          41.180       705.330            3.200
# 3396             66.180         133.360      1008.900            2.580
# 3398            137.140         277.200      1977.240            6.060
# 4490            209.840         159.900       423.610            5.590
# 4625              0.375           0.210         0.125            0.075
# 4626             73.540         115.970       928.300            5.820
# 4627            323.030         129.690      1540.370            8.780
# ...

# %%
f_d2 = t2.set_index('id')

# %%
r = f_d2.reset_index()

# %%
r
# Out:
#       id (HIST3H2A, 92815) (LIN7B, 64130) (LXN, 56925) (CNKSR2, 22866)  \
# 0   6980             48.52          186.4       536.45           48.52
# 1   6984             76.17          134.3       629.35           53.19
# 2   5936             24.46         147.06       591.22           56.68
# 3   6849             96.01         161.02       583.07           52.82
# 4   6968             72.52         221.86       890.44           23.08
# 5   5930             26.47         187.71       283.05           48.18
# 6   6745            178.77         285.03      1208.34            22.1
# 7   5931             34.75         148.09       438.59           30.78
# 8   6778             45.85         165.57       854.13           35.25
# 9   5939             30.12          138.1       647.07           74.06
# 10  2655             52.08         208.38      1127.35           49.91
# 11  6829             33.06         275.28       432.53           28.86
# ...

# %%
m_t2 = r[r['id'].isin(["3396","6777","6984","5645","5936","6147","6743","6981","6849","6595","6847","6969","6978","2665","6831","5930","2657","4627","6742","6983","6979","6970","6968","6975","6980","3398","6971","6828","4676","5931","6148","6776","2668","6745","2661","6145","2655","4490","5935","4625","6986","6829","4626","6985","6744","5932","6836","5933","6778","6146","6972","4632","6761","6835","6982","5939","2662"])]

# %%
m_t2
# Out:
#       id (HIST3H2A, 92815) (LIN7B, 64130) (LXN, 56925) (CNKSR2, 22866)  \
# 0   6980             48.52          186.4       536.45           48.52
# 1   6984             76.17          134.3       629.35           53.19
# 2   5936             24.46         147.06       591.22           56.68
# 3   6849             96.01         161.02       583.07           52.82
# 4   6968             72.52         221.86       890.44           23.08
# 5   5930             26.47         187.71       283.05           48.18
# 6   6745            178.77         285.03      1208.34            22.1
# 7   5931             34.75         148.09       438.59           30.78
# 8   6778             45.85         165.57       854.13           35.25
# 9   5939             30.12          138.1       647.07           74.06
# 10  2655             52.08         208.38      1127.35           49.91
# 11  6829             33.06         275.28       432.53           28.86
# ...

# %%
m_t2.set_index('id',inplace = True)

# %%
m_t2
# Out:
#      (HIST3H2A, 92815) (LIN7B, 64130) (LXN, 56925) (CNKSR2, 22866)  \
# id
# 6980             48.52          186.4       536.45           48.52
# 6984             76.17          134.3       629.35           53.19
# 5936             24.46         147.06       591.22           56.68
# 6849             96.01         161.02       583.07           52.82
# 6968             72.52         221.86       890.44           23.08
# 5930             26.47         187.71       283.05           48.18
# 6745            178.77         285.03      1208.34            22.1
# 5931             34.75         148.09       438.59           30.78
# 6778             45.85         165.57       854.13           35.25
# 5939             30.12          138.1       647.07           74.06
# 2655             52.08         208.38      1127.35           49.91
# 6829             33.06         275.28       432.53           28.86
# 3398            105.15         133.36      1208.34           66.18
# ...

# %%
m_t2 = m_t2.sort_values(by = 'id')

# %%
m_t = m_t.sort_values(by = 'id')

# %%
m_t.to_csv('tumorx.csv')

# %%
m_t2.to_csv('normalx.csv')

# %%
m_t
# Out:
#       (HIST3H2A, 92815)  (LIN7B, 64130)  (LXN, 56925)  (CNKSR2, 22866)  \
# id
# 2655             15.340         109.660       830.750            3.860
# 2657            187.710         256.780       713.110           21.010
# 2661            142.010         273.370      1233.750           12.180
# 2662            787.655          88.190      1019.955            5.120
# 2665            334.580         116.910       904.965            4.635
# 2668            590.730          41.180       705.330            3.200
# 3396             66.180         133.360      1008.900            2.580
# 3398            137.140         277.200      1977.240            6.060
# 4490            209.840         159.900       423.610            5.590
# 4625              0.375           0.210         0.125            0.075
# 4626             73.540         115.970       928.300            5.820
# 4627            323.030         129.690      1540.370            8.780
# ...

# %%
m_t.replace(0, np.nan, inplace=True)

# %%
m_t2.replace(0, np.nan, inplace=True)

# %% [markdown]
# foldchange calculations

# %%
import numpy as np

# %%
f = m_t/m_t2

# %%
fdc = np.log2(f)

# %%
fdc.to_csv('DGE_patients_foldchange.csv')
